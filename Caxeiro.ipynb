# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroAlves7/CaxeiroViajante/blob/main/Caxeiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Parâmetros do algoritmo
num_formigas = 50  # Número de formigas
num_iteracoes = 100  # Número de iterações
taxa_evaporacao = 0.5  # Taxa de evaporação do feromônio
alfa = 1  # Influência do feromônio
beta = 2  # Influência da distância

#cidade[0,1] = 20


# Matriz de distâncias entre as cidades
#distancias = np.array([
#    [0, 2, 3, 5],
#    [2, 0, 4, 8],
#    [3, 4, 0, 6],
#    [5, 8, 6, 0]
#])

distancias = np.array([
    [0, 20, 999999, 999999, 999999, 999999, 999999, 29, 999999, 999999, 999999, 29, 37, 999999, 999999, 999999, 999999, 999999],
    [20, 0, 25, 999999, 999999, 999999, 999999, 28, 999999, 999999, 999999, 39, 999999, 999999, 999999, 999999, 999999, 999999],
    [999999, 25, 0, 25, 999999, 999999, 999999, 30, 999999, 999999, 999999, 999999, 54, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 25, 0, 39, 32, 42, 999999, 23, 33, 999999, 999999, 999999, 56, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 39, 0, 12, 26, 999999, 999999, 19, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 32, 12, 0, 17, 999999, 999999, 35, 30, 999999, 999999, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 42, 26, 17, 0, 999999, 999999, 999999, 38, 999999, 999999, 999999, 999999, 999999, 999999, 999999],
    [29, 28, 30, 999999, 999999, 999999, 999999, 0, 999999, 999999, 999999, 25, 22, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 23, 999999, 999999, 999999, 999999, 0, 26, 999999, 999999, 34, 37, 999999, 43, 999999, 999999],
    [999999, 999999, 999999, 33, 19, 35, 999999, 999999, 26, 0, 24, 999999, 999999, 30, 19, 999999, 999999, 999999],
    [999999, 999999, 999999, 999999, 999999, 30, 38, 999999, 999999, 24, 0, 999999, 999999, 999999, 26, 999999, 999999, 36],
    [29, 39, 999999, 999999, 999999, 999999, 999999, 25, 999999, 999999, 999999, 0, 27, 999999, 999999, 43, 999999, 999999],
    [37, 999999, 54, 999999, 999999, 999999, 999999, 22, 34, 999999, 999999, 27, 0, 24, 999999, 19, 999999, 999999],
    [999999, 999999, 999999, 56, 999999, 999999, 999999, 999999, 37, 30, 999999, 999999, 24, 0, 20, 19, 17, 999999],
    [999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 19, 26, 999999, 999999, 20, 0, 999999, 18, 21],
    [999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 43, 999999, 999999, 43, 19, 19, 999999, 0, 26, 999999],
    [999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 36, 999999, 999999, 999999, 21, 26, 0, 15],
    [999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 17, 18, 26, 15, 0]
])


# Inicialização dos feromônios
feromonios = np.ones(distancias.shape) / len(distancias)

# Loop principal
for _ in range(num_iteracoes):
    # Inicialização dos caminhos percorridos pelas formigas
    caminhos = np.zeros((num_formigas, len(distancias)), dtype=int)

    for k in range(num_formigas):
        # Criação de um caminho para cada formiga
        cidades_visitadas = [0]  # Começar na cidade 0
        cidades_nao_visitadas = list(range(1, len(distancias)))

        for _ in range(len(distancias) - 1):
            # Escolha da próxima cidade baseada nas regras do ACO
            probabilidade = (feromonios[cidades_visitadas[-1], cidades_nao_visitadas] ** alfa) * \
                ((1.0 / distancias[cidades_visitadas[-1], cidades_nao_visitadas]) ** beta)
            probabilidade = probabilidade / np.sum(probabilidade)

            proxima_cidade = np.random.choice(cidades_nao_visitadas, p=probabilidade)
            cidades_visitadas.append(proxima_cidade)
            cidades_nao_visitadas.remove(proxima_cidade)

        caminhos[k] = cidades_visitadas

    # Cálculo das distâncias percorridas por cada formiga
    distancias_percorridas = np.zeros(num_formigas)
    for k in range(num_formigas):
        for i in range(len(distancias) - 1):
            distancias_percorridas[k] += distancias[caminhos[k, i], caminhos[k, i + 1]]
        distancias_percorridas[k] += distancias[caminhos[k, -1], caminhos[k, 0]]

    # Atualização dos feromônios
    feromonios *= taxa_evaporacao
    for k in range(num_formigas):
        for i in range(len(distancias) - 1):
            feromonios[caminhos[k, i], caminhos[k, i + 1]] += 1.0 / distancias_percorridas[k]
        feromonios[caminhos[k, -1], caminhos[k, 0]] += 1.0 / distancias_percorridas[k]

# Melhor caminho encontrado
melhor_caminho = caminhos[np.argmin(distancias_percorridas)]
melhor_distancia = np.min(distancias_percorridas)

print("Melhor caminho encontrado:", melhor_caminho + 1)
print("Melhor distância encontrada:", melhor_distancia)
# Out:
# Melhor caminho encontrado: [ 1 12 13 14 15 10  5  6  7 11 18 17 16  9  4  3  2  8]
# Melhor distância encontrada: 455.0

# %%
import numpy as np

# Parâmetros do algoritmo
num_formigas = 50  # Número de formigas
num_iteracoes = 100  # Número de iterações
taxa_evaporacao = 0.5  # Taxa de evaporação do feromônio
alfa = 1  # Influência do feromônio
beta = 2  # Influência da distância

# Matriz de distâncias entre as cidades
distancias = np.array([
    [0, 20, 999999, 999999, 999999, 999999, 999999, 29, 999999, 999999, 999999, 29, 37, 999999, 999999, 999999, 999999, 999999],
    [20, 0, 25, 999999, 999999, 999999, 999999, 28, 999999, 999999, 999999, 39, 999999, 999999, 999999, 999999, 999999, 999999],
    [999999, 25, 0, 25, 999999, 999999, 999999, 30, 999999, 999999, 999999, 999999, 54, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 25, 0, 39, 32, 42, 999999, 23, 33, 999999, 999999, 999999, 56, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 39, 0, 12, 26, 999999, 999999, 19, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 32, 12, 0, 17, 999999, 999999, 35, 30, 999999, 999999, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 42, 26, 17, 0, 999999, 999999, 999999, 38, 999999, 999999, 999999, 999999, 999999, 999999, 999999],
    [29, 28, 30, 999999, 999999, 999999, 999999, 0, 999999, 999999, 999999, 25, 22, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 23, 999999, 999999, 999999, 999999, 0, 26, 999999, 999999, 34, 37, 999999, 43, 999999, 999999],
    [999999, 999999, 999999, 33, 19, 35, 999999, 999999, 26, 0, 29, 999999, 999999, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 999999, 999999, 30, 38, 999999, 999999, 29, 0, 999999, 999999, 999999, 20, 999999, 999999, 999999],
    [29, 39, 999999, 999999, 999999, 999999, 999999, 25, 999999, 999999, 999999, 0, 999999, 999999, 999999, 999999, 999999, 999999],
    [37, 999999, 54, 999999, 999999, 999999, 999999, 22, 34, 999999, 999999, 999999, 0, 999999, 999999, 999999, 999999, 999999],
    [999999, 999999, 999999, 56, 999999, 999999, 999999, 999999, 37, 999999, 999999, 999999, 999999, 0, 999999, 35, 999999, 24],
    [999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 20, 999999, 999999, 999999, 0, 999999, 999999, 18],
    [999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 43, 999999, 999999, 999999, 999999, 35, 999999, 0, 21, 999999],
    [999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 21, 0, 19],
    [999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 999999, 24, 18, 999999, 19, 0]
])

num_cidades = len(distancias)  # Número de cidades

# Inicialização dos feromônios
feromonios = np.ones((num_cidades, num_cidades))

# Função para calcular a probabilidade de escolha de uma cidade
def calcular_probabilidade(cidade_atual, cidades_restantes):
    denominador = np.sum((feromonios[cidade_atual, cidades_restantes] ** alfa) * ((1.0 / distancias[cidade_atual, cidades_restantes]) ** beta))
    probabilidades = ((feromonios[cidade_atual, cidades_restantes] ** alfa) * ((1.0 / distancias[cidade_atual, cidades_restantes]) ** beta)) / denominador
    return probabilidades

# Loop principal
melhor_distancia = np.inf
melhor_caminho = []

for _ in range(num_iteracoes):
    caminhos = np.zeros((num_formigas, num_cidades), dtype=int)

    for i in range(num_formigas):
        visitados = []
        cidade_atual = np.random.randint(num_cidades)
        visitados.append(cidade_atual)

        for _ in range(num_cidades - 1):
            cidades_restantes = list(set(range(num_cidades)) - set(visitados))
            probabilidades = calcular_probabilidade(cidade_atual, cidades_restantes)
            proxima_cidade = np.random.choice(cidades_restantes, p=probabilidades)
            visitados.append(proxima_cidade)
            cidade_atual = proxima_cidade

        caminhos[i] = visitados

    distancias_caminhos = np.zeros(num_formigas)

    for i in range(num_formigas):
        for j in range(num_cidades - 1):
            distancias_caminhos[i] += distancias[caminhos[i, j], caminhos[i, j + 1]]

    melhor_formiga = np.argmin(distancias_caminhos)
    melhor_distancia_iteracao = distancias_caminhos[melhor_formiga]

    if melhor_distancia_iteracao < melhor_distancia:
        melhor_distancia = melhor_distancia_iteracao
        melhor_caminho = caminhos[melhor_formiga]

    for i in range(num_formigas):
        for j in range(num_cidades - 1):
            feromonios[caminhos[i, j], caminhos[i, j + 1]] += 1.0 / distancias_caminhos[i]

    feromonios *= taxa_evaporacao

print("Melhor caminho encontrado:", melhor_caminho + 1)
print("Melhor distância encontrada:", melhor_distancia)
# Out:
# Melhor caminho encontrado: [13  8 12  1  2  3  4  9 10  5  6  7 11 15 18 17 16 14]
# Melhor distância encontrada: 394.0

# %%
import numpy as np

# Parâmetros do algoritmo
num_formigas = 50  # Número de formigas
num_iteracoes = 100  # Número de iterações
taxa_evaporacao = 0.5  # Taxa de evaporação do feromônio
alfa = 1  # Influência do feromônio
beta = 2  # Influência da distância

distancias = np.array([
    [0, 20, 999999, 29, 29, 999999],
    [20, 0, 25, 28, 39, 999999],
    [999999, 25, 0, 30, 999999, 54],
    [29, 28, 30, 0, 25, 22],
    [29,39,999999, 25, 0, 27],
    [999999, 999999, 54, 22, 27,0]
])


# Inicialização dos feromônios
feromonios = np.ones(distancias.shape) / len(distancias)

# Loop principal
for _ in range(num_iteracoes):
    # Inicialização dos caminhos percorridos pelas formigas
    caminhos = np.zeros((num_formigas, len(distancias))).astype(int)

    for k in range(num_formigas):
        # Criação de um caminho para cada formiga
        cidades_visitadas = [0]  # Começar na cidade 0
        cidades_nao_visitadas = list(range(1, len(distancias)))

        for _ in range(len(distancias) - 1):
            # Escolha da próxima cidade baseada nas regras do ACO
            probabilidade = (feromonios[cidades_visitadas[-1], cidades_nao_visitadas] ** alfa) * \
                ((1.0 / distancias[cidades_visitadas[-1], cidades_nao_visitadas]) ** beta)
            probabilidade = probabilidade / np.sum(probabilidade)

            proxima_cidade = np.random.choice(cidades_nao_visitadas, p=probabilidade)
            cidades_visitadas.append(proxima_cidade)
            cidades_nao_visitadas.remove(proxima_cidade)

        caminhos[k] = cidades_visitadas

    # Cálculo das distâncias percorridas por cada formiga
    distancias_percorridas = np.zeros(num_formigas)
    for k in range(num_formigas):
        for i in range(len(distancias) - 1):
            distancias_percorridas[k] += distancias[caminhos[k, i], caminhos[k, i + 1]]
        distancias_percorridas[k] += distancias[caminhos[k, -1], caminhos[k, 0]]

    # Atualização dos feromônios
    feromonios *= taxa_evaporacao
    for k in range(num_formigas):
        for i in range(len(distancias) - 1):
            feromonios[caminhos[k, i], caminhos[k, i + 1]] += 1.0 / distancias_percorridas[k]
        feromonios[caminhos[k, -1], caminhos[k, 0]] += 1.0 / distancias_percorridas[k]

# Melhor caminho encontrado
melhor_caminho = caminhos[np.argmin(distancias_percorridas)]
melhor_distancia = np.min(distancias_percorridas)

print("Melhor caminho encontrado:", melhor_caminho + 1)
print("Melhor distância encontrada:", melhor_distancia)
# Out:
# Melhor caminho encontrado: [1 2 3 4 6 5]
# Melhor distância encontrada: 153.0
